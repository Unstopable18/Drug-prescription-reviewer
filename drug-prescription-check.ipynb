# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/VDeshmukhCemtrex/Datasets/main/drug.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161297 entries, 0 to 161296
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     161297 non-null  int64
#  1   drugName     161297 non-null  object
#  2   condition    160398 non-null  object
#  3   review       161297 non-null  object
#  4   rating       161297 non-null  int64
#  5   date         161297 non-null  object
#  6   usefulCount  161297 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 8.6+ MB

# %%
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160398 entries, 0 to 161296
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     160398 non-null  int64
#  1   drugName     160398 non-null  object
#  2   condition    160398 non-null  object
#  3   review       160398 non-null  object
#  4   rating       160398 non-null  int64
#  5   date         160398 non-null  object
#  6   usefulCount  160398 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 9.8+ MB

# %%
df.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  160398.000000  160398.000000  160398.000000
# mean   115957.147309       6.995923      28.097613
# std     67015.899492       3.272303      36.457876
# min         2.000000       1.000000       0.000000
# 25%     58065.250000       5.000000       6.000000
# 50%    115845.500000       8.000000      16.000000
# 75%    173826.750000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
df.sample(5)
# Out:
#         uniqueID                            drugName                condition  \
# 84819     209330                               Zomig                 Migraine
# 3346      130382                      Levonorgestrel  Emergency Contraception
# 16188      73808   Ethinyl estradiol / norethindrone                     Acne
# 7301       57368                         Oxymorphone                     Pain
# 120492    104493  Ethinyl estradiol / levonorgestrel            Birth Control
#
#                                                    review  rating       date  \
# 84819   "I was prescribed Zomig by my Neurologist, I h...      10  15-Sep-10
# 3346    "Took the pill about 1-2 hours after unprotect...      10  22-Jul-13
# 16188   "I&#039;m 22, and this is my first time being ...       3  24-Sep-12
# 7301    "I&#039;ve got scoliosis and disc herniation. ...       7  24-Dec-11
# 120492  "I love this pill! I was on it for three month...       9   3-Nov-11
#
#         usefulCount
# ...

# %%
df["drugName"].nunique()
# Out:
# 3431

# %%
df["condition"].nunique()
# Out:
# 884

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  160398.000000  160398.000000  160398.000000
# mean   115957.147309       6.995923      28.097613
# std     67015.899492       3.272303      36.457876
# min         2.000000       1.000000       0.000000
# 25%     58065.250000       5.000000       6.000000
# 50%    115845.500000       8.000000      16.000000
# 75%    173826.750000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
df[df['usefulCount'] == 0].count()[0]
# Out:
# 6217

# %%
df[(df['usefulCount'] == 0) & df['rating'] >= 8].count()[0]
# Out:
# 0

# %%
df[df['usefulCount'] == 0]['rating'].mean()
# Out:
# 5.800064339713688

# %%
df[df['usefulCount'] > 1000].count()[0]
# Out:
# 4

# %%
df[df['usefulCount'] > 1000]['rating'].mean()
# Out:
# 10.0

# %%
ufc_df1000=df[df['usefulCount'] > 1000].reset_index(drop=True)

# %%
group_ufc_df1000=ufc_df1000.groupby(['condition','rating','usefulCount','drugName']).size().reset_index()
group_ufc_df1000
# Out:
#        condition  rating  usefulCount        drugName  0
# 0  Birth Control      10         1247  Levonorgestrel  1
# 1  Birth Control      10         1247          Mirena  1
# 2     Depression      10         1291      Sertraline  1
# 3     Depression      10         1291          Zoloft  1

# %%
ufc_df500=df[(df['usefulCount'] > 500)&(df['usefulCount'] < 1000)].reset_index(drop=True)

# %%
group_ufc_df500=ufc_df500.groupby(['condition','rating','usefulCount','drugName']).size().reset_index()
group_ufc_df500
# Out:
#              condition  rating  usefulCount        drugName  0
# 0              Anxiety       9          585          BuSpar  1
# 1              Anxiety      10          520          BuSpar  1
# 2              Anxiety      10          520       Buspirone  1
# 3              Anxiety      10          526      Alprazolam  1
# 4              Anxiety      10          526           Xanax  1
# 5   Anxiety and Stress       8          693          Celexa  1
# 6   Anxiety and Stress       8          693      Citalopram  1
# 7        Birth Control      10          505  Levonorgestrel  1
# 8        Birth Control      10          505          Mirena  1
# 9        Birth Control      10          730        Implanon  1
# 10          Depression       8          771          Celexa  1
# 11          Depression       8          771      Citalopram  1
# 12          Depression       9          513         Viibryd  1
# 13          Depression       9          559          Celexa  1
# ...

# %%
avg_rated=df[(df.usefulCount>=df.usefulCount.mean()) & (df.rating>=df.rating.mean())]
avg_rated
# Out:
#         uniqueID                  drugName              condition  \
# 1          95260                Guanfacine                   ADHD
# 4          35696  Buprenorphine / naloxone      Opiate Dependence
# 7         102654              Aripiprazole        Bipolar Disorde
# 11         75612            L-methylfolate             Depression
# 17        219869             Amitriptyline            ibromyalgia
# ...          ...                       ...                    ...
# 161282    229036                 Tadalafil   Erectile Dysfunction
# 161287    132177                    Ativan                Anxiety
# 161292    191035                   Campral     Alcohol Dependence
# 161295     47128        Thyroid desiccated    Underactive Thyroid
# 161296    215220              Lubiprostone  Constipation, Chronic
#
#                                                    review  rating       date  \
# 1       "My son is halfway through his fourth week of ...       8  27-Apr-10
# ...

# %%
import plotly.express as px

# %%
avg_rated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42580 entries, 1 to 161296
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   uniqueID     42580 non-null  int64
#  1   drugName     42580 non-null  object
#  2   condition    42580 non-null  object
#  3   review       42580 non-null  object
#  4   rating       42580 non-null  int64
#  5   date         42580 non-null  object
#  6   usefulCount  42580 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 2.6+ MB

# %%
px.histogram(avg_rated,x="rating",y="usefulCount")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:920, in IPythonDisplayFormatter.__call__(self, obj)
#     918 method = get_real_method(obj, self.print_method)
#     919 if method is not None:
# --> 920     method()
#     921     return True
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...
